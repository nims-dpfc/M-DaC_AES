# %%
import subprocess
subprocess.run(["jamp2csv.exe", "data036.A", "data036.A.csv"])
# Out:
# CompletedProcess(args=['jamp2csv.exe', 'data036.A', 'data036.A.csv'], returncode=4294967291)

# %%
# %run -i jampcsv2graph.py "data036.A.csv" --jupytermode
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="463ee762-b9cd-4f03-8551-165d4a4f75d2" class="plotly-graph-div" style="height:700px; width:800px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("463ee762-b9cd-4f03-8551-165d4a4f75d2")) {
#                     Plotly.newPlot(
# ...
